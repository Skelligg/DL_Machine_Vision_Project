# %% [markdown]
# # 4. CNN Built from Scratch
#
# **Student:** Student 2
#
# ## Purpose
# - Design simple CNN architecture from scratch
# - Implement custom CNN model (similar to course examples)
# - Train for equal number of epochs as pretrained models
# - Compare performance with transfer learning approaches
# - Analyze trade-offs between custom and pretrained models

# %%
# TODO: Import libraries and load setup from previous notebooks

# %%
# TODO: Design CNN architecture
# - 3-5 convolutional layers with ReLU activation
# - MaxPooling layers after conv blocks
# - Flatten and fully connected layers
# - Output layer with num_classes units
# - Document architecture rationale

# %%
# TODO: Implement CNN class using nn.Module
# - __init__ with layer definitions
# - forward method
# - Proper weight initialization

# %%
# TODO: Set up training for scratch CNN
# - Use SAME optimizer and learning rate as baseline
# - Use SAME batch size as baseline
# - Train for EQUAL number of epochs as pretrained models
# - Use same loss function (CrossEntropyLoss)

# %%
# TODO: Initialize TensorBoard logger for scratch CNN

# %%
# TODO: Train scratch CNN model
# - Use training loop identical to pretrained model
# - Log metrics to TensorBoard
# - Save checkpoints

# %%
# TODO: Evaluate scratch CNN on test set
# - Compute accuracy, precision, recall, F1-score
# - Generate confusion matrix

# %%
# TODO: Plot training curves for scratch CNN
# - Training loss vs epochs
# - Validation loss vs epochs
# - Training accuracy vs epochs
# - Validation accuracy vs epochs

# %%
# TODO: Write scratch CNN analysis (1-2 paragraphs)
# - Discuss performance vs pretrained models
# - Analyze convergence behavior
# - Note overfitting/underfitting patterns

# %%
# TODO: Save scratch CNN checkpoint
# - Location: saved_models/cnn_scratch/model_checkpoint.pt
