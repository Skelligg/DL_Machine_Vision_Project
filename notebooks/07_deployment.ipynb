# %% [markdown]
# # 7. Model Deployment with FastAPI and Docker
#
# **Student:**
#
# ## Purpose
# - Serve the best-performing model using FastAPI
# - Create REST API endpoints for model inference
# - Build Docker container for deployment
# - Test API endpoints and containerized application
# - Document deployment setup and usage instructions

# %%
# TODO: Import necessary libraries
# fastapi, uvicorn, torch, torchvision, pillow, pydantic

# %%
# TODO: Load the best-performing model
# - Load model weights from training
# - Set model to evaluation mode

# %%
# TODO: Define Pydantic models for API requests/responses
# - ImageInput: for image upload
# - PredictionResponse: for model output

# %%
# TODO: Create FastAPI application
# - Initialize FastAPI app
# - Create health check endpoint
# - Create prediction endpoint with image preprocessing

# %%
# TODO: Test API endpoints locally
# - Send test requests with sample images
# - Verify predictions and response format

# %%
# TODO: Create Dockerfile
# - Base image (python:3.10-slim or similar)
# - Install dependencies
# - Copy model weights and application code
# - Set entrypoint for uvicorn server

# %%
# TODO: Create requirements.txt for Docker
# - List all dependencies with versions

# %%
# TODO: Build and test Docker container
# - Build image with docker build
# - Run container with docker run
# - Test API endpoints in containerized environment

# %%
# TODO: Document deployment setup and usage
# - Document API endpoint specification
# - Provide deployment instructions
# - Include example usage and curl commands
