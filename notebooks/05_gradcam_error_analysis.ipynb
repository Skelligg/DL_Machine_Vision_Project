# %% [markdown]
# # 5. Grad-CAM and Error Analysis
#
# **Student:** Student 3
#
# ## Purpose
# - Implement Grad-CAM for model explainability
# - Generate ≥5 visualizations of model decision-making
# - Analyze at least 3 misclassified cases
# - Interpret what features the model focuses on
# - Discuss potential causes of errors

# %%
# TODO: Import libraries
# torch, matplotlib, cv2 for visualization

# %%
# TODO: Load baseline pretrained model
# - Load checkpoint from saved_models/baseline_pretrained/

# %%
# TODO: Implement or import Grad-CAM
# - Use pytorch-grad-cam package or implement custom
# - Test on sample image to verify correctness

# %%
# TODO: Visualization 1 - Correctly classified example 1
# - Select diverse example image
# - Generate Grad-CAM heatmap
# - Overlay on original image
# - Write explanation of what model focuses on

# %%
# TODO: Visualization 2 - Correctly classified example 2

# %%
# TODO: Visualization 3 - Correctly classified example 3

# %%
# TODO: Misclassified Case 1
# - Find misclassified sample
# - Show original image
# - Show predicted vs true class
# - Generate Grad-CAM heatmap
# - Analyze: What features is model focusing on?
# - Discuss possible causes (ambiguous classes, feature over-reliance, etc.)

# %%
# TODO: Misclassified Case 2

# %%
# TODO: Misclassified Case 3

# %%
# TODO: Additional visualizations (≥5 total)
# - Can include more misclassified cases or edge cases
# - Show different types of model behaviors

# %%
# TODO: Common patterns in model errors
# - Analyze misclassified cases collectively
# - Identify systematic biases or failure modes
# - Write summary of error patterns

# %%
# TODO: Feature interpretation summary
# - What features does the model rely on?
# - Are there features it over-relies on?
# - Do learned features make sense for the task?
